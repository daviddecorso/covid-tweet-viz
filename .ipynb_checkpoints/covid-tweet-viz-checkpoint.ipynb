# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df1 = pd.read_csv("covid19_tweets.csv")

# %%
df1.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df1.shape
# Out:
# (125101, 13)

# %%
df1.groupby('user_location')['user_location'].agg('count')
# Out:
# user_location
# \nˢᵒᵐᵉʷʰᵉʳᵉ\n🖤          4
#                        19
#      Cathlamet, Wa.     1
#    Canada 🇨🇦🍁🛶🌲         1
#    WorldWide            1
#                        ..
# 🥰🥰                      1
# 🦄                       1
# 🦄🌈❤️🧡💛💚💙💜🌈🦄             3
# 🦅💛💛💙❤🌋                  1
# 🪐                       4
# Name: user_location, Length: 21398, dtype: int64

# %%
df2 = df1.drop(['user_name', 'user_description', 'user_created', 'user_followers', 'user_friends', 'user_favourites', 'user_verified', 'text', 'source', 'is_retweet'],axis='columns')
df2.head()
# Out:
#           user_location                 date  \
# 0            astroworld  2020-07-25 12:27:21
# 1          New York, NY  2020-07-25 12:27:17
# 2      Pewee Valley, KY  2020-07-25 12:27:14
# 3  Stuck in the Middle   2020-07-25 12:27:10
# 4     Jammu and Kashmir  2020-07-25 12:27:08
#
#                             hashtags
# 0                                NaN
# 1                                NaN
# 2                        ['COVID19']
# 3                        ['COVID19']
# 4  ['CoronaVirusUpdates', 'COVID19']

# %%
df2.isnull().sum()
# Out:
# user_location    25192
# date                 0
# hashtags         35971
# dtype: int64

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# user_location    0
# date             0
# hashtags         0
# dtype: int64

# %%
df3.head()
# Out:
#           user_location                 date  \
# 2      Pewee Valley, KY  2020-07-25 12:27:14
# 3  Stuck in the Middle   2020-07-25 12:27:10
# 4     Jammu and Kashmir  2020-07-25 12:27:08
# 5           Новоро́ссия  2020-07-25 12:27:06
# 6       Gainesville, FL  2020-07-25 12:27:03
#
#                             hashtags
# 2                        ['COVID19']
# 3                        ['COVID19']
# 4  ['CoronaVirusUpdates', 'COVID19']
# 5         ['coronavirus', 'covid19']
# 6          ['COVID19', 'Recruiting']

# %%
df3.user_location.unique()
# Out:
# array(['Pewee Valley, KY', 'Stuck in the Middle ', 'Jammu and Kashmir',
#        ..., 'Global Analysis', 'The Mazzaroth', 'Across Africa'],
#       dtype=object)

# %%
df3.hashtags.unique()
# Out:
# array(["['COVID19']", "['CoronaVirusUpdates', 'COVID19']",
#        "['coronavirus', 'covid19']", ..., "['COVID19', 'FRONTLINE']",
#        "['Agility', 'COVID19']", "['Russia', 'coronavirusvaccine']"],
#       dtype=object)

# %%
def date_to_day(x):
    tokens = x.split(' ')
    if len(tokens) == 2:
        return (tokens[0])

# %%
date_to_day('2020-07-25 12:27:14')
# Out:
# '2020-07-25'

# %%
df4 = df3.copy()
df4['date'] = df4['date'].apply(date_to_day)

# %%
df4.head()
# Out:
#           user_location        date                           hashtags
# 2      Pewee Valley, KY  2020-07-25                        ['COVID19']
# 3  Stuck in the Middle   2020-07-25                        ['COVID19']
# 4     Jammu and Kashmir  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5           Новоро́ссия  2020-07-25         ['coronavirus', 'covid19']
# 6       Gainesville, FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
df4.date.unique()
# Out:
# array(['2020-07-25', '2020-07-24', '2020-07-26', '2020-07-27',
#        '2020-07-28', '2020-07-29', '2020-07-30', '2020-07-31',
#        '2020-08-01', '2020-08-02', '2020-08-04', '2020-08-06',
#        '2020-08-07', '2020-08-08', '2020-08-09', '2020-08-10',
#        '2020-08-11', '2020-08-12', '2020-08-13'], dtype=object)

# %%
print(df4.head(20))
# Out:
#                                         user_location        date  \
# 2                                    Pewee Valley, KY  2020-07-25
# 3                                Stuck in the Middle   2020-07-25
# 4                                   Jammu and Kashmir  2020-07-25
# 5                                         Новоро́ссия  2020-07-25
# 6                                     Gainesville, FL  2020-07-25
# 9                          👇🏻location at link below👇🏻  2020-07-25
# 11                                   Dhaka,Bangladesh  2020-07-25
# 12  Hotel living - various cities!  Who needs a ho...  2020-07-25
# 13                                             Africa  2020-07-25
# 15                                    Nagaland, India  2020-07-25
# 17                                           Brussels  2020-07-25
# 23                                     100+ countries  2020-07-25
# 24                                               Graz  2020-07-25
# ...

# %%
df4.head(20)
# Out:
#                                         user_location        date  \
# 2                                    Pewee Valley, KY  2020-07-25
# 3                                Stuck in the Middle   2020-07-25
# 4                                   Jammu and Kashmir  2020-07-25
# 5                                         Новоро́ссия  2020-07-25
# 6                                     Gainesville, FL  2020-07-25
# 9                          👇🏻location at link below👇🏻  2020-07-25
# 11                                   Dhaka,Bangladesh  2020-07-25
# 12  Hotel living - various cities!  Who needs a ho...  2020-07-25
# 13                                             Africa  2020-07-25
# 15                                    Nagaland, India  2020-07-25
# 17                                           Brussels  2020-07-25
# 23                                     100+ countries  2020-07-25
# 24                                               Graz  2020-07-25
# ...

# %%
df4['user_location'].unique()
# Out:
# array(['Pewee Valley, KY', 'Stuck in the Middle ', 'Jammu and Kashmir',
#        ..., 'Global Analysis', 'The Mazzaroth', 'Across Africa'],
#       dtype=object)

# %%
dfDropTest = df4.drop(df4['user_location'].unique(), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d062e2d3da2f> in <module>
# ----> 1 dfDropTest = df4.drop(df4['user_location'].unique(), inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
uniqueLocations = df4['user_location'].unique()

# %%
dfDropTest = df4.copy()

# %%
dfDropTest.head()
# Out:
#           user_location        date                           hashtags
# 2      Pewee Valley, KY  2020-07-25                        ['COVID19']
# 3  Stuck in the Middle   2020-07-25                        ['COVID19']
# 4     Jammu and Kashmir  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5           Новоро́ссия  2020-07-25         ['coronavirus', 'covid19']
# 6       Gainesville, FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
df4['user_location'].unique(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6423a5a1d11a> in <module>
# ----> 1 df4['user_location'].unique(20)
#
# TypeError: unique() takes 1 positional argument but 2 were given

# %%
df4['user_location'].unique()
# Out:
# array(['Pewee Valley, KY', 'Stuck in the Middle ', 'Jammu and Kashmir',
#        ..., 'Global Analysis', 'The Mazzaroth', 'Across Africa'],
#       dtype=object)

# %%
print(uniqueLocations[4])
# Out:
# Gainesville, FL

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-64c2895ea0ec> in <module>
# ----> 1 print(uniqueLocations.len)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'len'

# %%
print(len(uniqueLocations))
# Out:
# 16833

# %%
dfStateParseTest = df4.copy()

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        return (tokens[1].strip())

# %%
city_to_state('Stuart, FL')
# Out:
# 'FL'

# %%
df5 = df4.copy()

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state

# %%
city_to_state('Stuart, FL')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a50fc2e5d7a2> in <module>
# ----> 1 city_to_state('Stuart, FL')
#
# <ipython-input-40-a64948dcff1d> in city_to_state(x)
#       3     if len(tokens) == 2:
#       4         state = tokens[1].strip
# ----> 5         if len(state) == 2:
#       6             return state
#
# TypeError: object of type 'builtin_function_or_method' has no len()

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state

# %%
city_to_state('Stuart, FL')
# Out:
# 'FL'

# %%
city_to_state('Stuart, Floooridasdasdsad')

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        else:
            return x

# %%
city_to_state('Stuart, Floooridasdasdsad')
# Out:
# 'Stuart, Floooridasdasdsad'

# %%
city_to_state('Stuart, FL')
# Out:
# 'FL'

# %%
df5['user_location'] = df4['user_location'].apply(city_to_state)

# %%
df5.head()
# Out:
#   user_location        date                           hashtags
# 2            KY  2020-07-25                        ['COVID19']
# 3          None  2020-07-25                        ['COVID19']
# 4          None  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5          None  2020-07-25         ['coronavirus', 'covid19']
# 6            FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
def convert_city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        else:
            return x

# %%
df5 = df4.copy()

# %%
def convert_city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        else:
            return x
    else:
        return x

# %%
convert_city_to_state('blah blah blah')
# Out:
# 'blah blah blah'

# %%
df5['user_location'] = df4['user_location'].apply(city_to_state)
df5.head()
# Out:
#   user_location        date                           hashtags
# 2            KY  2020-07-25                        ['COVID19']
# 3          None  2020-07-25                        ['COVID19']
# 4          None  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5          None  2020-07-25         ['coronavirus', 'covid19']
# 6            FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
df5 = df4.copy()

# %%
df5.head()
# Out:
#           user_location        date                           hashtags
# 2      Pewee Valley, KY  2020-07-25                        ['COVID19']
# 3  Stuck in the Middle   2020-07-25                        ['COVID19']
# 4     Jammu and Kashmir  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5           Новоро́ссия  2020-07-25         ['coronavirus', 'covid19']
# 6       Gainesville, FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
df5['user_location'] = df5['user_location'].apply(convert_city_to_state)
df5.head()
# Out:
#           user_location        date                           hashtags
# 2                    KY  2020-07-25                        ['COVID19']
# 3  Stuck in the Middle   2020-07-25                        ['COVID19']
# 4     Jammu and Kashmir  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5           Новоро́ссия  2020-07-25         ['coronavirus', 'covid19']
# 6                    FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
df5['user_location'].unique()
# Out:
# array(['KY', 'Stuck in the Middle ', 'Jammu and Kashmir', ...,
#        'Global Analysis', 'The Mazzaroth', 'Across Africa'], dtype=object)

# %%
df5.shape
# Out:
# (71474, 3)

# %%
df5.user_location.describe()
# Out:
# count     71474
# unique    14833
# top       India
# freq       1994
# Name: user_location, dtype: object

# %%
df5.date.describe()
# Out:
# count          71474
# unique            19
# top       2020-07-25
# freq            9535
# Name: date, dtype: object

# %%
df6 = df6[~df5['user_location'].unique()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-44d5d7ed4bcb> in <module>
# ----> 1 df6 = df6[~df5['user_location'].unique()]
#
# NameError: name 'df6' is not defined

# %%
df6 = df5[~(df5['user_location'].unique())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-124769641f38> in <module>
# ----> 1 df6 = df5[~(df5['user_location'].unique())]
#
# TypeError: bad operand type for unary ~: 'str'

# %%
df6 = df5.copy()

# %%
df6 = df6.drop(df6['user_location'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-cff953ed939e> in <module>
# ----> 1 df6 = df6.drop(df6['user_location'].unique())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
uniqueLocations = df6.['user_location'].unique()
# Out:
#   File "<ipython-input-67-d3139d3953d6>", line 1
#     uniqueLocations = df6.['user_location'].unique()
#                           ^
# SyntaxError: invalid syntax

# %%
df6 = df6.drop(df6.user_location.unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-0bba9eeeecaf> in <module>
# ----> 1 df6 = df6.drop(df6.user_location.unique())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
uniqueLocations = df6.user_location.unique()

# %%
print(uniqueLocations)
# Out:
# ['KY' 'Stuck in the Middle ' 'Jammu and Kashmir' ... 'Global Analysis'
#  'The Mazzaroth' 'Across Africa']

# %%
df6 = df6[df6['user_location'].duplicated(keep=False)]

# %%
df6.head()
# Out:
#         user_location        date  \
# 2                  KY  2020-07-25
# 4   Jammu and Kashmir  2020-07-25
# 5         Новоро́ссия  2020-07-25
# 6                  FL  2020-07-25
# 11   Dhaka,Bangladesh  2020-07-25
#
#                                              hashtags
# 2                                         ['COVID19']
# 4                   ['CoronaVirusUpdates', 'COVID19']
# 5                          ['coronavirus', 'covid19']
# 6                           ['COVID19', 'Recruiting']
# 11  ['logo', 'graphicdesigner', 'logodesign', 'log...

# %%
df6.describe()
# Out:
#        user_location        date     hashtags
# count          61591       61591        61591
# unique          4950          19        26734
# top            India  2020-07-25  ['COVID19']
# freq            1994        8208        18638

# %%
df5.describe()
# Out:
#        user_location        date     hashtags
# count          71474       71474        71474
# unique         14833          19        31164
# top            India  2020-07-25  ['COVID19']
# freq            1994        9535        21772

# %%
df6.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\cleaned_covid_tweets.csv')

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA'):
            return tokens[0]

# %%
city_to_state('California, USA')
# Out:
# 'California'

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA' || state == 'US' || state == 'United States'):
            return tokens[0]
# Out:
#   File "<ipython-input-78-9647fb2bd0dd>", line 7
#     if (state == 'USA' || state == 'US' || state == 'United States'):
#                         ^
# SyntaxError: invalid syntax

# %%
def city_to_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA' or state == 'US' or state == 'United States'):
            return tokens[0]

# %%
def parse_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA' or state == 'US' or state == 'United States'):
            return tokens[0]

# %%
parse_state('New York, United States')
# Out:
# 'New York'

# %%
def parse_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA' or state == 'US' or state == 'United States'):
            return tokens[0]
    return null

# %%
parse_state(' egrhrkjgb krgreighekr gkrejg bkjrgbjk')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-7e35289c0b05> in <module>
# ----> 1 parse_state(' egrhrkjgb krgreighekr gkrejg bkjrgbjk')
#
# <ipython-input-82-b4c893817a26> in parse_state(x)
#       7         if (state == 'USA' or state == 'US' or state == 'United States'):
#       8             return tokens[0]
# ----> 9     return null
#
# NameError: name 'null' is not defined

# %%
def parse_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA' or state == 'US' or state == 'United States'):
            return tokens[0]
    return None

# %%
parse_state(' egrhrkjgb krgreighekr gkrejg bkjrgbjk')

# %%
def parse_state(x):
    tokens = x.split(',')
    if len(tokens) == 2:
        state = tokens[1].strip()
        if len(state) == 2:
            return state
        if (state == 'USA' or state == 'US' or state == 'United States'):
            return tokens[0]
    return 'Null'

# %%
parse_state(' egrhrkjgb krgreighekr gkrejg bkjrgbjk')
# Out:
# 'Null'

# %%
statesOnlyDF['user_location'] = df4['user_location'].apply(city_to_state)
statesOnlyDF.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-ce394d2d2b6c> in <module>
# ----> 1 statesOnlyDF['user_location'] = df4['user_location'].apply(city_to_state)
#       2 statesOnlyDF.head()
#
# NameError: name 'statesOnlyDF' is not defined

# %%
statesOnlyDF = df4.copy()

# %%
statesOnlyDF['user_location'] = df4['user_location'].apply(city_to_state)
statesOnlyDF.head()
# Out:
#   user_location        date                           hashtags
# 2            KY  2020-07-25                        ['COVID19']
# 3          None  2020-07-25                        ['COVID19']
# 4          None  2020-07-25  ['CoronaVirusUpdates', 'COVID19']
# 5          None  2020-07-25         ['coronavirus', 'covid19']
# 6            FL  2020-07-25          ['COVID19', 'Recruiting']

# %%
statesOnlyDF.head(50)
# Out:
#    user_location        date  \
# 2             KY  2020-07-25
# 3           None  2020-07-25
# 4           None  2020-07-25
# 5           None  2020-07-25
# 6             FL  2020-07-25
# 9           None  2020-07-25
# 11          None  2020-07-25
# 12          None  2020-07-25
# 13          None  2020-07-25
# 15          None  2020-07-25
# 17          None  2020-07-25
# 23          None  2020-07-25
# 24          None  2020-07-25
# 25          None  2020-07-25
# 26          None  2020-07-25
# 27            NY  2020-07-25
# 28          None  2020-07-25
# 30          None  2020-07-25
# 31          None  2020-07-25
# 32            FL  2020-07-25
# 33          None  2020-07-25
# 36          None  2020-07-25
# 38            UK  2020-07-25
# 39          None  2020-07-25
# 40          None  2020-07-25
# 41          None  2020-07-25
# 42          None  2020-07-25
# 43          None  2020-07-25
# 45          None  2020-07-25
# 46          None  2020-07-25
# 56            NY  2020-07-25
# ...

# %%
statesOnlyDF = df4.copy()

# %%
statesOnlyDF['user_location'] = df4['user_location'].apply(parse_state)
statesOnlyDF.head(50)
# Out:
#    user_location        date  \
# 2             KY  2020-07-25
# 3           Null  2020-07-25
# 4           Null  2020-07-25
# 5           Null  2020-07-25
# 6             FL  2020-07-25
# 9           Null  2020-07-25
# 11          Null  2020-07-25
# 12          Null  2020-07-25
# 13          Null  2020-07-25
# 15          Null  2020-07-25
# 17          Null  2020-07-25
# 23          Null  2020-07-25
# 24          Null  2020-07-25
# 25          Null  2020-07-25
# 26          Null  2020-07-25
# 27            NY  2020-07-25
# 28          Null  2020-07-25
# 30          Null  2020-07-25
# 31          Null  2020-07-25
# 32            FL  2020-07-25
# 33          Null  2020-07-25
# 36          Null  2020-07-25
# 38            UK  2020-07-25
# 39          Null  2020-07-25
# 40          Null  2020-07-25
# 41          Null  2020-07-25
# 42          Null  2020-07-25
# 43          Null  2020-07-25
# 45          Null  2020-07-25
# 46          Null  2020-07-25
# 56            NY  2020-07-25
# ...

# %%
statesOnlyDF[statesOnlyDF.user_location != 'Null']
# Out:
#        user_location        date  \
# 2                 KY  2020-07-25
# 6                 FL  2020-07-25
# 27                NY  2020-07-25
# 32                FL  2020-07-25
# 38                UK  2020-07-25
# ...              ...         ...
# 125054            UK  2020-08-13
# 125065            GA  2020-08-13
# 125077            UK  2020-08-13
# 125089            CA  2020-08-13
# 125096            GA  2020-08-13
#
#                                                  hashtags
# 2                                             ['COVID19']
# 6                               ['COVID19', 'Recruiting']
# 27                                            ['COVID19']
# 32                                  ['covid19', 'Africa']
# 38                     ['BorisJohnson', '5COBRA', 'Five']
# ...                                                   ...
# 125054                  ['manchesterlockdown', 'COVID19']
# 125065                           ['coronavirus', 'scams']
# ...

# %%
statesOnlyDF = statesOnlyDF[statesOnlyDF.user_location != 'Null']

# %%
statesOnlyDF.head(20)
# Out:
#     user_location        date  \
# 2              KY  2020-07-25
# 6              FL  2020-07-25
# 27             NY  2020-07-25
# 32             FL  2020-07-25
# 38             UK  2020-07-25
# 56             NY  2020-07-25
# 57             LA  2020-07-25
# 64             GA  2020-07-25
# 67             NY  2020-07-25
# 71             CO  2020-07-25
# 77             DC  2020-07-25
# 91             UK  2020-07-25
# 104            NY  2020-07-25
# 107            NY  2020-07-25
# 115            FL  2020-07-25
# 131            NY  2020-07-25
# 159       Florida  2020-07-25
# 169            NY  2020-07-25
# 180            IL  2020-07-25
# 184            FL  2020-07-25
#
#                                              hashtags
# 2                                         ['COVID19']
# 6                           ['COVID19', 'Recruiting']
# 27                                        ['COVID19']
# 32                              ['covid19', 'Africa']
# ...

# %%
statesOnlyDF.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\US_cleaned_covid_tweets.csv')

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
print(us_state_abbrev)
# Out:
# {'Alabama': 'AL', 'Alaska': 'AK', 'American Samoa': 'AS', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'District of Columbia': 'DC', 'Florida': 'FL', 'Georgia': 'GA', 'Guam': 'GU', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Northern Mariana Islands': 'MP', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Puerto Rico': 'PR', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virgin Islands': 'VI', 'Virginia': 'VA', 'Washin
# ...

# %%
dictTest = statesOnlyDF.copy()

# %%
dictTest['user_location'].map(us_state_abbrev)
# Out:
# 2         NaN
# 6         NaN
# 27        NaN
# 32        NaN
# 38        NaN
#          ...
# 125054    NaN
# 125065    NaN
# 125077    NaN
# 125089    NaN
# 125096    NaN
# Name: user_location, Length: 13585, dtype: object

# %%
dictTest.head()
# Out:
#    user_location        date                            hashtags
# 2             KY  2020-07-25                         ['COVID19']
# 6             FL  2020-07-25           ['COVID19', 'Recruiting']
# 27            NY  2020-07-25                         ['COVID19']
# 32            FL  2020-07-25               ['covid19', 'Africa']
# 38            UK  2020-07-25  ['BorisJohnson', '5COBRA', 'Five']

# %%
dictTest.head(50)
# Out:
#       user_location        date  \
# 2                KY  2020-07-25
# 6                FL  2020-07-25
# 27               NY  2020-07-25
# 32               FL  2020-07-25
# 38               UK  2020-07-25
# 56               NY  2020-07-25
# 57               LA  2020-07-25
# 64               GA  2020-07-25
# 67               NY  2020-07-25
# 71               CO  2020-07-25
# 77               DC  2020-07-25
# 91               UK  2020-07-25
# 104              NY  2020-07-25
# 107              NY  2020-07-25
# 115              FL  2020-07-25
# 131              NY  2020-07-25
# 159         Florida  2020-07-25
# 169              NY  2020-07-25
# 180              IL  2020-07-25
# 184              FL  2020-07-25
# 214   Massachusetts  2020-07-25
# 231              MI  2020-07-25
# 236              TX  2020-07-25
# 237   Massachusetts  2020-07-25
# 238              DC  2020-07-25
# 244              WI  2020-07-25
# 250              IL  2020-07-25
# 253              IN  2020-07-25
# ...

# %%
dictTest['user_location'].map(us_state_abbrev).fillna(dictTest['user_location'])
# Out:
# 2         KY
# 6         FL
# 27        NY
# 32        FL
# 38        UK
#           ..
# 125054    UK
# 125065    GA
# 125077    UK
# 125089    CA
# 125096    GA
# Name: user_location, Length: 13585, dtype: object

# %%
dictTest = dictTest['user_location'].map(us_state_abbrev).fillna(dictTest['user_location'])

# %%
dictTest.head(50)
# Out:
# 2                 KY
# 6                 FL
# 27                NY
# 32                FL
# 38                UK
# 56                NY
# 57                LA
# 64                GA
# 67                NY
# 71                CO
# 77                DC
# 91                UK
# 104               NY
# 107               NY
# 115               FL
# 131               NY
# 159               FL
# 169               NY
# 180               IL
# 184               FL
# 214               MA
# 231               MI
# 236               TX
# 237               MA
# 238               DC
# 244               WI
# 250               IL
# 253               IN
# 255               OH
# 257               NJ
# 260               MO
# 261               NY
# 267               MO
# 268               OK
# 272               FL
# 301    South Florida
# 302               NY
# 309       Launch Pad
# 315               TX
# 335               nc
# 337               MD
# 355               DC
# 357               NY
# ...

# %%
dictTest = statesOnlyDF.copy()

# %%
dictTest['user_location'] = dictTest['user_location'].map(us_state_abbrev).fillna(dictTest['user_location'])

# %%
dictTest.head(50)
# Out:
#      user_location        date  \
# 2               KY  2020-07-25
# 6               FL  2020-07-25
# 27              NY  2020-07-25
# 32              FL  2020-07-25
# 38              UK  2020-07-25
# 56              NY  2020-07-25
# 57              LA  2020-07-25
# 64              GA  2020-07-25
# 67              NY  2020-07-25
# 71              CO  2020-07-25
# 77              DC  2020-07-25
# 91              UK  2020-07-25
# 104             NY  2020-07-25
# 107             NY  2020-07-25
# 115             FL  2020-07-25
# 131             NY  2020-07-25
# 159             FL  2020-07-25
# 169             NY  2020-07-25
# 180             IL  2020-07-25
# 184             FL  2020-07-25
# 214             MA  2020-07-25
# 231             MI  2020-07-25
# 236             TX  2020-07-25
# 237             MA  2020-07-25
# 238             DC  2020-07-25
# 244             WI  2020-07-25
# 250             IL  2020-07-25
# 253             IN  2020-07-25
# 255             OH  2020-07-25
# ...

# %%
statesAbr = dictTest.copy()

# %%
statesAbr.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\US_cleaned_covid_tweets.csv')

# %%
def state_abbr_format(x):
    if (len(x) != 2):
# Out:
#   File "<ipython-input-113-bbaf8a71b9dd>", line 2
#     if (len(x) != 2):
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
def state_abbr_format(x):
    if (len(x) != 2
        return 'Null'
    return x.toUpper()
# Out:
#   File "<ipython-input-114-ae89091d5172>", line 3
#     return 'Null'
#          ^
# SyntaxError: invalid syntax

# %%
def state_abbr_format(x):
    if (len(x) != 2)
        return 'Null'
    return x.toUpper()
# Out:
#   File "<ipython-input-115-808855979eab>", line 2
#     if (len(x) != 2)
#                     ^
# SyntaxError: invalid syntax

# %%
def state_abbr_format(x):
    if (!len(x) == 2)
        return 'Null'
    return x.toUpper()
# Out:
#   File "<ipython-input-116-fba1d0632fd3>", line 2
#     if (!len(x) == 2)
#         ^
# SyntaxError: invalid syntax

# %%
def state_abbr_format(x):
    if (len(x) > 2 or len(x) < 2):
        return 'Null'
    return x.toUpper()

# %%
state_abbr_format('fl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-393c04cbed25> in <module>
# ----> 1 state_abbr_format('fl')
#
# <ipython-input-117-4f025dae6a03> in state_abbr_format(x)
#       2     if (len(x) > 2 or len(x) < 2):
#       3         return 'Null'
# ----> 4     return x.toUpper()
#
# AttributeError: 'str' object has no attribute 'toUpper'

# %%
def state_abbr_format(x):
    if (len(x) > 2 or len(x) < 2):
        return 'Null'
    return x.upper()

# %%
state_abbr_format('fl')
# Out:
# 'FL'

# %%
def state_abbr_format(x):
    if (len(x) > 2 or len(x) < 2 or !x.isalpha()):
        return 'Null'
    return x.upper()
# Out:
#   File "<ipython-input-121-a1c7951bcff5>", line 2
#     if (len(x) > 2 or len(x) < 2 or !x.isalpha()):
#                                     ^
# SyntaxError: invalid syntax

# %%
def state_abbr_format(x):
    if (len(x) > 2 or len(x) < 2 or not x.isalpha()):
        return 'Null'
    return x.upper()

# %%
state_abbr_format('h!')
# Out:
# 'Null'

# %%
state_abbr_format('fl')
# Out:
# 'FL'

# %%
state_abbr_format('abc')
# Out:
# 'Null'

# %%
statesAbr['user_location'] = statesAbr['user_location'].apply(state_abbr_format)

# %%
statesAbr.head()
# Out:
#    user_location        date                            hashtags
# 2             KY  2020-07-25                         ['COVID19']
# 6             FL  2020-07-25           ['COVID19', 'Recruiting']
# 27            NY  2020-07-25                         ['COVID19']
# 32            FL  2020-07-25               ['covid19', 'Africa']
# 38            UK  2020-07-25  ['BorisJohnson', '5COBRA', 'Five']

# %%
statesAbr.head(50)
# Out:
#     user_location        date  \
# 2              KY  2020-07-25
# 6              FL  2020-07-25
# 27             NY  2020-07-25
# 32             FL  2020-07-25
# 38             UK  2020-07-25
# 56             NY  2020-07-25
# 57             LA  2020-07-25
# 64             GA  2020-07-25
# 67             NY  2020-07-25
# 71             CO  2020-07-25
# 77             DC  2020-07-25
# 91             UK  2020-07-25
# 104            NY  2020-07-25
# 107            NY  2020-07-25
# 115            FL  2020-07-25
# 131            NY  2020-07-25
# 159            FL  2020-07-25
# 169            NY  2020-07-25
# 180            IL  2020-07-25
# 184            FL  2020-07-25
# 214            MA  2020-07-25
# 231            MI  2020-07-25
# 236            TX  2020-07-25
# 237            MA  2020-07-25
# 238            DC  2020-07-25
# 244            WI  2020-07-25
# 250            IL  2020-07-25
# 253            IN  2020-07-25
# 255            OH  2020-07-25
# 257            NJ  2020-07-25
# ...

# %%
statesAbr = statesAbr[statesAbr.user_location != 'Null']

# %%
statesAbr.head(50)
# Out:
#     user_location        date  \
# 2              KY  2020-07-25
# 6              FL  2020-07-25
# 27             NY  2020-07-25
# 32             FL  2020-07-25
# 38             UK  2020-07-25
# 56             NY  2020-07-25
# 57             LA  2020-07-25
# 64             GA  2020-07-25
# 67             NY  2020-07-25
# 71             CO  2020-07-25
# 77             DC  2020-07-25
# 91             UK  2020-07-25
# 104            NY  2020-07-25
# 107            NY  2020-07-25
# 115            FL  2020-07-25
# 131            NY  2020-07-25
# 159            FL  2020-07-25
# 169            NY  2020-07-25
# 180            IL  2020-07-25
# 184            FL  2020-07-25
# 214            MA  2020-07-25
# 231            MI  2020-07-25
# 236            TX  2020-07-25
# 237            MA  2020-07-25
# 238            DC  2020-07-25
# 244            WI  2020-07-25
# 250            IL  2020-07-25
# 253            IN  2020-07-25
# 255            OH  2020-07-25
# 257            NJ  2020-07-25
# ...

# %%
statesAbr.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\US_cleaned_covid_tweets.csv')

# %%
nyt = pd.read_csv("covid19_tweets.csv")

# %%
nyt.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
nyt = pd.read_csv("covid-us-states-nyt.csv")

# %%
nyt.head()
# Out:
#         date       state  fips   cases  deaths  confirmed_cases  \
# 0  8/13/2020     Alabama     1  105557    1890         101496.0
# 1  8/13/2020      Alaska     2    4748      25           4748.0
# 2  8/13/2020     Arizona     4  190823    4385              NaN
# 3  8/13/2020    Arkansas     5   51766     582          51766.0
# 4  8/13/2020  California     6  600291   10868         600291.0
#
#    confirmed_deaths  probable_cases  probable_deaths
# 0            1821.0          4061.0             69.0
# 1              25.0             0.0              0.0
# 2               NaN             NaN              NaN
# 3             582.0             0.0              0.0
# 4           10868.0             0.0              0.0

# %%
nyt = nyt.drop(['fips', 'confirmed_cases', 'confirmed_deaths', 'probable_cases', 'probable_deaths'],axis='columns')
nyt.head()
# Out:
#         date       state   cases  deaths
# 0  8/13/2020     Alabama  105557    1890
# 1  8/13/2020      Alaska    4748      25
# 2  8/13/2020     Arizona  190823    4385
# 3  8/13/2020    Arkansas   51766     582
# 4  8/13/2020  California  600291   10868

# %%
dictTest['state'] = dictTest['state'].map(us_state_abbrev).fillna(dictTest['state'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-b5449b0dcd46> in <module>
# ...

# %%
nyt['state'] = nyt['state'].map(us_state_abbrev).fillna(nyt['state'])
nyt.head()
# Out:
#         date state   cases  deaths
# 0  8/13/2020    AL  105557    1890
# 1  8/13/2020    AK    4748      25
# 2  8/13/2020    AZ  190823    4385
# 3  8/13/2020    AR   51766     582
# 4  8/13/2020    CA  600291   10868

# %%
nyt.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\nyt_cleaned_covid_totals.csv')

# %%
nyt_daily = pd.read_csv("daily-us-states.csv")

# %%
nyt_daily.head()
# Out:
#         date       state   cases  deaths
# 0  7/25/2020     Alabama   78130    1456
# 1  7/25/2020      Alaska    2866      18
# 2  7/25/2020     Arizona  160055    3288
# 3  7/25/2020    Arkansas   37981     399
# 4  7/25/2020  California  453327    8428

# %%
nyt_daily['state'] = nyt_daily['state'].map(us_state_abbrev).fillna(nyt_daily['state'])
nyt.head()
# Out:
#         date state   cases  deaths
# 0  8/13/2020    AL  105557    1890
# 1  8/13/2020    AK    4748      25
# 2  8/13/2020    AZ  190823    4385
# 3  8/13/2020    AR   51766     582
# 4  8/13/2020    CA  600291   10868

# %%
nyt_daily.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\nyt_cleaned_daily-us-states.csv')

# %%
statesAbr.head()
# Out:
#    user_location        date                            hashtags
# 2             KY  2020-07-25                         ['COVID19']
# 6             FL  2020-07-25           ['COVID19', 'Recruiting']
# 27            NY  2020-07-25                         ['COVID19']
# 32            FL  2020-07-25               ['covid19', 'Africa']
# 38            UK  2020-07-25  ['BorisJohnson', '5COBRA', 'Five']

# %%
statesCount = statesAbr.pivot_table(index=['user_location'], aggfunc='size')
statesCount.head()
# Out:
# user_location
# AB    20
# AK    31
# AL    71
# AR    63
# AU     1
# dtype: int64

# %%
statesCount.head(50)
# Out:
# user_location
# AB      20
# AK      31
# AL      71
# AR      63
# AU       1
# AZ     202
# BC     135
# BE       2
# CA    1987
# CH       1
# CO     213
# CT     131
# DC     764
# DE      17
# EU       2
# FL     755
# GA     510
# GB       2
# GR       1
# GU       2
# HI      48
# IA      51
# ID      15
# IE       1
# IL     483
# IN     137
# IT       2
# KS      58
# KY      88
# LA     117
# MA     497
# MB       2
# MD     250
# ME      29
# MI     231
# MN     191
# MO     169
# MS      38
# MT      12
# MX       2
# NB       4
# NC     318
# ND      14
# NE      48
# NG       2
# NH      53
# NJ     282
# NL       3
# NM      64
# NS       2
# dtype: int64

# %%
statesCount.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\cleaned_state_tweet_total.csv')

# %%
nyt_daily.head()
# Out:
#         date state   cases  deaths
# 0  7/25/2020    AL   78130    1456
# 1  7/25/2020    AK    2866      18
# 2  7/25/2020    AZ  160055    3288
# 3  7/25/2020    AR   37981     399
# 4  7/25/2020    CA  453327    8428

# %%
stateAbr.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-4bc4a3b99935> in <module>
# ----> 1 stateAbr.head()
#
# NameError: name 'stateAbr' is not defined

# %%
statesAbr.head(50)
# Out:
#     user_location        date  \
# 2              KY  2020-07-25
# 6              FL  2020-07-25
# 27             NY  2020-07-25
# 32             FL  2020-07-25
# 38             UK  2020-07-25
# 56             NY  2020-07-25
# 57             LA  2020-07-25
# 64             GA  2020-07-25
# 67             NY  2020-07-25
# 71             CO  2020-07-25
# 77             DC  2020-07-25
# 91             UK  2020-07-25
# 104            NY  2020-07-25
# 107            NY  2020-07-25
# 115            FL  2020-07-25
# 131            NY  2020-07-25
# 159            FL  2020-07-25
# 169            NY  2020-07-25
# 180            IL  2020-07-25
# 184            FL  2020-07-25
# 214            MA  2020-07-25
# 231            MI  2020-07-25
# 236            TX  2020-07-25
# 237            MA  2020-07-25
# 238            DC  2020-07-25
# 244            WI  2020-07-25
# 250            IL  2020-07-25
# 253            IN  2020-07-25
# 255            OH  2020-07-25
# 257            NJ  2020-07-25
# ...

# %%
statesAbr.groupby(['user_location','date'])['user_location'].count()
# Out:
# user_location  date
# AB             2020-07-25    5
#                2020-07-26    2
#                2020-08-01    2
#                2020-08-02    2
#                2020-08-04    2
#                             ..
# WY             2020-08-09    2
# ℂ𝔸             2020-08-01    1
# 台灣             2020-08-10    1
#                2020-08-13    1
# 香港             2020-08-12    1
# Name: user_location, Length: 922, dtype: int64

# %%
tweets_by_date = statesAbr.groupby(['date','user_location'])['user_location'].count()

# %%
tweets_by_date.head()
# Out:
# date        user_location
# 2020-07-24  AR                1
#             AZ                2
#             CA               18
#             DC                3
#             FL                1
# Name: user_location, dtype: int64

# %%
tweets_by_date.head(50)
# Out:
# date        user_location
# 2020-07-24  AR                 1
#             AZ                 2
#             CA                18
#             DC                 3
#             FL                 1
#             IL                 1
#             MA                 2
#             MD                 1
#             MI                 1
#             MN                 1
#             NJ                 1
#             NM                 1
#             NV                 1
#             NY                 8
#             OH                 1
#             ON                 1
#             PA                 2
#             TX                 5
#             UT                 1
#             VA                 1
#             WA                 2
# 2020-07-25  AB                 5
#             AK                 2
#             AL                11
#             AR                 3
#             AZ                18
#             BC                18
# ...

# %%
tweets_by_date.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\daily_total_tweets_by_state.csv')

# %%
tbd = statesAbr.groupby(['date'])['date'].count()

# %%
tbd.head()
# Out:
# date
# 2020-07-24      55
# 2020-07-25    1535
# 2020-07-26     552
# 2020-07-27     664
# 2020-07-28     756
# Name: date, dtype: int64

# %%
tbd.head(50)
# Out:
# date
# 2020-07-24      55
# 2020-07-25    1535
# 2020-07-26     552
# 2020-07-27     664
# 2020-07-28     756
# 2020-07-29     522
# 2020-07-30     393
# 2020-07-31    1460
# 2020-08-01    1168
# 2020-08-02    1163
# 2020-08-04     548
# 2020-08-06    1296
# 2020-08-07     126
# 2020-08-08     808
# 2020-08-09     476
# 2020-08-10     818
# 2020-08-11     327
# 2020-08-12     337
# 2020-08-13     359
# Name: date, dtype: int64

# %%
tbd.head(100)
# Out:
# date
# 2020-07-24      55
# 2020-07-25    1535
# 2020-07-26     552
# 2020-07-27     664
# 2020-07-28     756
# 2020-07-29     522
# 2020-07-30     393
# 2020-07-31    1460
# 2020-08-01    1168
# 2020-08-02    1163
# 2020-08-04     548
# 2020-08-06    1296
# 2020-08-07     126
# 2020-08-08     808
# 2020-08-09     476
# 2020-08-10     818
# 2020-08-11     327
# 2020-08-12     337
# 2020-08-13     359
# Name: date, dtype: int64

# %%
tbd.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\daily_total_tweets.csv')

# %%
nyt_daily.head()
# Out:
#         date state   cases  deaths
# 0  7/25/2020    AL   78130    1456
# 1  7/25/2020    AK    2866      18
# 2  7/25/2020    AZ  160055    3288
# 3  7/25/2020    AR   37981     399
# 4  7/25/2020    CA  453327    8428

# %%
nyt_daily_total = nyt_daily.groupby('date')['date'].count()

# %%
nyt_daily_total.head()
# Out:
# date
# 7/25/2020    55
# 7/26/2020    55
# 7/27/2020    55
# 7/28/2020    55
# 7/29/2020    55
# Name: date, dtype: int64

# %%
nyt_daily_total = nyt_daily.groupby('date')['date'].sum()

# %%
nyt_daily_total.head()
# Out:
# date
# 7/25/2020    7/25/20207/25/20207/25/20207/25/20207/25/20207...
# 7/26/2020    7/26/20207/26/20207/26/20207/26/20207/26/20207...
# 7/27/2020    7/27/20207/27/20207/27/20207/27/20207/27/20207...
# 7/28/2020    7/28/20207/28/20207/28/20207/28/20207/28/20207...
# 7/29/2020    7/29/20207/29/20207/29/20207/29/20207/29/20207...
# Name: date, dtype: object

# %%
nyt_daily_total = nyt_daily.groupby('date')['cases'].sum()
nyt_daily_total.head()
# Out:
# date
# 7/25/2020    4190189
# 7/26/2020    4244406
# 7/27/2020    4303587
# 7/28/2020    4366697
# 7/29/2020    4433312
# Name: cases, dtype: int64

# %%
us = pd.read_csv("us.csv")

# %%
us.head()
# Out:
#         date    cases  deaths
# 0  7/25/2020  4190189  146312
# 1  7/26/2020  4244406  146752
# 2  7/27/2020  4303587  148448
# 3  7/28/2020  4366697  149775
# 4  7/29/2020  4433312  151170

# %%
us.cases.diff()
# Out:
# 0         NaN
# 1     54217.0
# 2     59181.0
# 3     63110.0
# 4     66615.0
# 5     69111.0
# 6     67736.0
# 7     58144.0
# 8     49325.0
# 9     47417.0
# 10    53393.0
# 11    53721.0
# 12    57511.0
# 13    60983.0
# 14    55197.0
# 15    48358.0
# 16    47125.0
# 17    53315.0
# 18    54187.0
# 19    53213.0
# Name: cases, dtype: float64

# %%
us = pd.read_csv("us.csv")

# %%
us = us.cases.diff()
us.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-df149cf6f39a> in <module>
# ----> 1 us = us.cases.diff()
#       2 us.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cases'

# %%
us.head()
# Out:
#    7/24/2020  4123413  145429
# 0  7/25/2020  4190189  146312
# 1  7/26/2020  4244406  146752
# 2  7/27/2020  4303587  148448
# 3  7/28/2020  4366697  149775
# 4  7/29/2020  4433312  151170

# %%
us = pd.read_csv("us.csv")
us = us.cases.diff()
us.head()
# Out:
# 0        NaN
# 1    66776.0
# 2    54217.0
# 3    59181.0
# 4    63110.0
# Name: cases, dtype: float64

# %%
us = pd.read_csv("us.csv")
us['cases'] = us.cases.diff()
us.head()
# Out:
#         date    cases  deaths
# 0  7/24/2020      NaN  145429
# 1  7/25/2020  66776.0  146312
# 2  7/26/2020  54217.0  146752
# 3  7/27/2020  59181.0  148448
# 4  7/28/2020  63110.0  149775

# %%
us.to_csv(r'C:\Users\dvddc\Documents\Coding\covid-viz\daily_us.csv')
